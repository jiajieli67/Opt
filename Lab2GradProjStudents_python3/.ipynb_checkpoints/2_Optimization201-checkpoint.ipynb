# %% [markdown]
# <center><img src="Fig/UGA.png" width="30%" height="30%"></center>
# <center><h3>Master of Science in Industrial and Applied Mathematics (MSIAM)  -- 1st year</h3></center>
# <hr>
# <center><h1>Optimization</h1></center>
# <center><h2>Lab2: Optimization 201 (3h)</h2></center>

# %% [markdown]
# # Projected gradient
#
# In this Lab, we continue to divide our optimization program into three parts:
# * the *run* environment, in which we test, run our program, and display results (this file!)
# * the *problem* part, which contains the function oracles, problem constraints, etc.
# * the *algorithmic* part, where the algorithms are coded.
#
# The main interest of such division is that these parts are interchangeable, meaning that, for instance, the algorithms of the third part can be used of a variety of problems. That is why such a decomposition is widely used. In this lab, we will re-use and adapt the problem part from previous lab. The algorithmic part is fundamentally new (well, adapted from the gradient methods from previous lab). We can now deal with some simple constraints such as positivity constraints of more generally interval constraints on the variables.
#
# In the present lab, you will use this division:
# * `2_Optimization201.ipynb` will be the *run* environment
# * `problem21.ipynb`, `problem22.ipynb`, .. will be the considered *problems* for this lab (see <a href="#pbs">Problems</a>)
# * `algoProjectedGradient.ipynb` will contain the projected gradient *algorithms* studied in this lab
#
# ---
#
# The following script will allow you to import *notebooks* as if you imported *python files* and will have to be executed at each time you launch Jupyter notebooks.

# %%
import start
from imp import reload

# %% [markdown]
# ---

# %% [markdown]
# # 1. Projected gradient algorithms on a simple function
#
# We begin by investigating <a href="#pb21">Problem 21</a>
#
# > Observe the 3D and level plots of the function.

# %%
import problem21 as pb21
# Out:
# importing notebook from problem21.ipynb

# %%
from plotLib import *
# %matplotlib inline

custom_3dplot( pb21.f, pb21.x1_min,pb21.x1_max,pb21.x2_min,pb21.x2_max,pb21.nb_points, pb21.vmin, pb21.vmax )
level_plot( pb21.f, pb21.x1_min,pb21.x1_max,pb21.x2_min,pb21.x2_max,pb21.nb_points, pb21.levels , pb21.title )

# %% [markdown]
# ### 1.a. simple projected gradient algorithm for positivoty constraints
#
# > Examine the functions and variables defined in `problem21.ipynb` <br/>
# > Complete the function `positivity_gradient_algorithm` as asked in `algoProjGradient.ipynb [Sec. 1a]` <br/>
# > Examine and run the cells below. Notably change the step size `step` and observe the different behaviors of the algorithm.

# %%
import algoProjGradient         # load our algoProGradient module (from notebook)
reload(algoProjGradient)        # reload the module if changed (and saved)
from algoProjGradient import *  # import all methods of the module into the current environment

import problem21 as pb21
reload(pb21) 

import numpy as np

#### Parameter we give at our algorithm (see algoGradient.ipynb)
PREC    = 0.001                     # Sought precision
ITE_MAX = 20                       # Max number of iterations
x0      = np.array( (2.0,2.0 ) )   # Initial point
step    = 1.5/pb21.L                # Stepsize 


##### Projected Gradient algorithm


x,x_tab = positivity_gradient_algorithm(pb21.f , pb21.f_grad , x0 , step , PREC , ITE_MAX )
# Out:
# importing notebook from algoProjGradient.ipynb
# importing notebook from problem21.ipynb
# ------------------------------------
#  Constant Stepsize projected gradient for positivity contraints
# ------------------------------------
# START    -- stepsize = 0.1875
# FINISHED -- 7 iterations / 0.000272s -- final value: 0.500061 at point (1.00,0.00)

# %% [markdown]
# ##### Plotting
#
# The following cell plots the iterates over the level sets of the minimized function.

# %%
from plotLib import *
# %matplotlib inline

level_points_plot( pb21.f , x_tab , pb21.x1_min,pb21.x1_max,pb21.x2_min,pb21.x2_max,pb21.nb_points, pb21.levels , pb21.title )

# %% [markdown]
# ### 1.b. simple projected gradient algorithm for interval  constraints
#
# > Examine the functions and variables defined in `problem21.ipynb` <br/>
# > Complete the function `interval_gradient_algorithm` as asked in `algoProjGradient.ipynb [Sec. 1a]` <br/>
# > Examine and run the cells below. Notably change the step size `step` and observe the different behaviors of the algorithm.
# > <br/>
# > Change also the interval bounds. Consider various interval  bounds [a, b], such that the minimum is within the bounds, or outside of the bounds, or a component is inside whereas the other is not.

# %%
import algoProjGradient         # load our algoProjGradient module (from notebook)
reload(algoProjGradient)        # reload the module if changed (and saved)
from algoProjGradient import *  # import all methods of the module into the current environment

import problem21 as pb21
reload(pb21) 

import numpy as np

#### Parameter we give at our algorithm (see algoGradient.ipynb)
PREC    = 0.01                     # Sought precision
ITE_MAX = 20                       # Max number of iterations
a = np.array( (-2,-2.0 ) )   # inf bounds 
b = np.array( (3.0,3.0 ) )   # sup bounds
# the interval constraints are a <= x <= b
x0      = np.array( (3.0,3.0 ) )   # Initial point
step    = 0.75/pb21.L                # Stepsize 


##### Projected Gradient algorithm


x,x_tab = interval_gradient_algorithm(pb21.f , pb21.f_grad , x0 , a , b , step , PREC , ITE_MAX )
# Out:
# importing notebook from algoProjGradient.ipynb
# importing notebook from problem21.ipynb
# ------------------------------------
#  Constant Stepsize projected gradient for interval constraints
# ------------------------------------
# START    -- stepsize = 0.09375
# FINISHED -- 11 iterations / 0.000785s -- final value: 0.000309 at point (1.00,-0.49)

# %% [markdown]
# ##### Plotting
#
# The following cell plots the iterates over the level sets of the minimized function.

# %%
from plotLib import *
# %matplotlib inline

level_points_plot( pb21.f , x_tab , pb21.x1_min,pb21.x1_max,pb21.x2_min,pb21.x2_max,pb21.nb_points, pb21.levels , pb21.title )

# %% [markdown]
# ---
# # 2. More involved functions
#
# Now, we investigate other functions and examine the behavior of gradient algorithms in these cases.

# %% [markdown]
# ### 2.a  Shaper functions
#
# <a href="#pb3">Problem 2</a> features a sharper function.

# %%
import problem2 as pb2

from plotLib import *
# %matplotlib inline

custom_3dplot( pb2.f, pb2.x1_min,pb2.x1_max,pb2.x2_min,pb2.x2_max,pb2.nb_points, pb2.vmin, pb2.vmax )
level_plot( pb2.f, pb2.x1_min,pb2.x1_max,pb2.x2_min,pb2.x2_max,pb2.nb_points, pb2.levels , pb2.title )
# Out:
# importing notebook from problem2.ipynb

# %% [markdown]
# > Run and compare constant stepsize projected gradient for various interval constraints.

# %%
import algoProjGradient         # load our algoProjGradient module (from notebook)
reload(algoProjGradient)        # reload the module if changed (and saved)
from algoProjGradient import *  # import all methods of the module into the current environment

import problem2 as pb2
reload(pb2) 

import numpy as np

#### Parameter we give at our algorithm (see algoGradient.ipynb)
PREC    = 0.01                     # Sought precision
ITE_MAX = 20                        # Max number of iterations
x0      = np.array( (1.,3.0 ) )   # Initial point
a = np.array( (-2,-2.0 ) )   # inf bounds 
b = np.array( (3.0,3.0 ) )   # sup bounds
# the interval constraints are a <= x <= b

##### Projected Gradient algorithm (interval)
step    = 1/pb2.L#1.0/pb2.L                # Stepsize 

x,x_tab = interval_gradient_algorithm(pb2.f , pb2.f_grad , x0 , a , b , step , PREC , ITE_MAX )
# Out:
# importing notebook from algoProjGradient.ipynb
# importing notebook from problem2.ipynb
# ------------------------------------
#  Constant Stepsize projected gradient for interval constraints
# ------------------------------------
# START    -- stepsize = 0.125
# FINISHED -- 15 iterations / 0.000778s -- final value: 0.001240 at point (3.00,1.04)

# %% [markdown]
# ---
# ##### Comparing gradient algorithm and Newton method

# %%
from plotLib import *
# %matplotlib inline

##### visualisation
level_points_plot( pb2.f , x_tab , pb2.x1_min,pb2.x1_max,pb2.x2_min,pb2.x2_max,pb2.nb_points, pb2.levels , pb2.title )

# %% [markdown]
# ### 2.b Non-convex functions
#
# <a href="#pb3">Problem 3</a> features classical Rosenbrock non-convex function.

# %%
import problem3 as pb3

from plotLib import *
# %matplotlib inline

custom_3dplot( pb3.f, pb3.x1_min,pb3.x1_max,pb3.x2_min,pb3.x2_max,pb3.nb_points, pb3.vmin, pb3.vmax )
level_plot( pb3.f, pb3.x1_min,pb3.x1_max,pb3.x2_min,pb3.x2_max,pb3.nb_points, pb3.levels , pb3.title )
# Out:
# importing notebook from problem3.ipynb

# %% [markdown]
# > Run and compare constant stepsize projected gradient for various interval constraints.

# %%
import algoProjGradient         # load our algoProjGradient module (from notebook)
reload(algoProjGradient)        # reload the module if changed (and saved)
from algoProjGradient import *  # import all methods of the module into the current environment

import problem3 as pb3
reload(pb3) 

import numpy as np

#### Parameter we give at our algorithm (see algoGradient.ipynb)
PREC    = 0.01                     # Sought precision
ITE_MAX = 20                       # Max number of iterations
x0      = np.array( (0.0,0.0 ) )   # Initial point
a = np.array( (-2,-2.0 ) )   # inf bounds 
b = np.array( (3.0,3.0 ) )   # sup bounds
# the interval constraints are a <= x <= b

##### Projected Gradient algorithm (interval)
step    =  0.1                     # Stepsize 
x,x_tab = interval_gradient_algorithm(pb3.f , pb3.f_grad , x0 , a , b , step , PREC , ITE_MAX )
# x,x_tab = interval_gradient_algorithm(pb3.f , pb3.f_grad , x0 , a , b , step , PREC , ITE_MAX )
# Out:
# importing notebook from algoProjGradient.ipynb
# importing notebook from problem3.ipynb
# ------------------------------------
#  Constant Stepsize gradient
# ------------------------------------
# START    -- stepsize = 0.1
# gtested = (1.60,-8.00)
#
# gtested = (-14.69,159.68)
#
# gtested = (2584.22,-855.68)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# gtested = (7204.00,0.00)
#
# gtested = (-806.00,0.00)
#
# FINISHED -- 19 iterations / 0.000561s -- final value: 109.000000 at point (-2.00,3.00)

# %% [markdown]
# ---
# ##### Projected gradient algorithm on pb3

# %%
from plotLib import *
# %matplotlib inline


##### comparison
level_points_plot( pb3.f , x_tab , pb3.x1_min,pb3.x1_max,pb3.x2_min,pb3.x2_max,pb3.nb_points, pb3.levels , pb3.title )
#level_points_plot( pb3.f , xn_tab , pb3.x1_min,pb3.x1_max,pb3.x2_min,pb3.x2_max,pb3.nb_points, pb3.levels , pb3.title )
#level_2points_plot( pb3.f , x_tab , xn_tab ,  pb3.x1_min, pb3.x1_max, pb3.x2_min, pb3.x2_max, pb3.nb_points,  pb3.levels ,  pb3.title )

# %% [markdown]
# > try and correct the gradient algorithm behavior by creating an adaptative stepsize algorithm in `algoProjGradient.ipynb [Sec. 2a and 2b]`.

# %% [markdown]
# ### 2.c Non-convex functions with mutliple minimizers
#
# <a href="#pb4">Problem 4</a> features a smooth non-convex function with two minimizers.

# %%
import problem4 as pb4

from plotLib import *
# %matplotlib inline

custom_3dplot( pb4.f, pb4.x1_min,pb4.x1_max,pb4.x2_min,pb4.x2_max,pb4.nb_points, pb4.vmin, pb4.vmax )
level_plot( pb4.f, pb4.x1_min,pb4.x1_max,pb4.x2_min,pb4.x2_max,pb4.nb_points, pb4.levels , pb4.title )

# %% [markdown]
# > Run the constant and adaptive stepsize interval projeted gradient algorithms. Change the initialization and observe the final point. Change the interval conatraints also.

# %%
import algoProjGradient         # load our algoProjGradient module (from notebook)
reload(algoProjGradient)        # reload the module if changed (and saved)
from algoProjGradient import *  # import all methods of the module into the current environment

import problem4 as pb4
reload(pb4) 

import numpy as np

#### Parameter we give at our algorithm (see algoGradient.ipynb)
PREC    = 0.01                     # Sought precision
ITE_MAX = 100                       # Max number of iterations
x0      = np.array( (1.5,0.55 ) )   # Initial point
a = np.array( (-2,-2.0 ) )   # inf bounds 
b = np.array( (3.0,3.0 ) )   # sup bounds
# the interval constraints are a <= x <= b

##### Gradient algorithm
step    =  0.1                     # Stepsize 
x,x_tab = interval_gradient_algorithm(pb4.f , pb4.f_grad , x0 , a, b, step , PREC , ITE_MAX )
# Out:
# importing notebook from algoProjGradient.ipynb
# importing notebook from problem4.ipynb
# ------------------------------------
#  Constant Stepsize gradient
# ------------------------------------
# START    -- stepsize = 0.1
# gtested = (-0.04,0.02)
#
# gtested = (-0.04,0.02)
#
# gtested = (-0.05,0.02)
#
# gtested = (-0.05,0.01)
#
# gtested = (-0.06,0.01)
#
# gtested = (-0.07,0.00)
#
# gtested = (-0.07,-0.00)
#
# gtested = (-0.08,-0.01)
#
# gtested = (-0.10,-0.01)
#
# gtested = (-0.11,-0.02)
#
# gtested = (-0.13,-0.03)
#
# gtested = (-0.15,-0.03)
#
# gtested = (-0.17,-0.04)
#
# gtested = (-0.19,-0.05)
#
# gtested = (-0.22,-0.06)
#
# gtested = (-0.26,-0.08)
#
# gtested = (-0.30,-0.09)
#
# gtested = (-0.34,-0.10)
#
# gtested = (-0.39,-0.12)
#
# gtested = (-0.45,-0.14)
#
# gtested = (-0.51,-0.16)
#
# gtested = (-0.57,-0.18)
#
# gtested = (-0.64,-0.21)
#
# gtested = (-0.72,-0.23)
#
# gtested = (-0.79,-0.26)
#
# gtested = (-0.85,-0.28)
#
# gtested = (-0.90,-0.29)
#
# gtested = (-0.92,-0.30)
#
# gtested = (-0.92,-0.30)
#
# gtested = (-0.88,-0.29)
#
# gtested = (-0.81,-0.27)
#
# gtested = (-0.72,-0.24)
#
# gtested = (-0.61,-0.20)
#
# gtested = (-0.49,-0.16)
#
# gtested = (-0.38,-0.12)
#
# gtested = (-0.29,-0.09)
#
# gtested = (-0.21,-0.07)
#
# gtested = (-0.15,-0.05)
#
# gtested = (-0.11,-0.03)
#
# gtested = (-0.07,-0.02)
#
# gtested = (-0.05,-0.02)
#
# gtested = (-0.04,-0.01)
#
# gtested = (-0.02,-0.01)
#
# gtested = (-0.02,-0.00)
#
# gtested = (-0.01,-0.00)
#
# gtested = (-0.01,-0.00)
#
# gtested = (-0.01,-0.00)
#
# gtested = (-0.00,-0.00)
#
# gtested = (-0.00,-0.00)
#
# gtested = (-0.00,0.00)
#
# gtested = (-0.00,0.00)
#
# gtested = (-0.00,0.00)
#
# gtested = (-0.00,0.00)
#
# gtested = (-0.00,0.00)
#
# gtested = (-0.00,0.00)
#
# gtested = (-0.00,0.00)
#
# FINISHED -- 55 iterations / 0.001577s -- final value: 0.000000 at point (3.00,1.00)

# %% [markdown]
# ---
# ##### Comparing gradient algorithm and Newton method

# %%
from plotLib import *
# %matplotlib inline


##### comparison
level_points_plot( pb4.f , x_tab , pb4.x1_min,pb4.x1_max,pb4.x2_min,pb4.x2_max,pb4.nb_points, pb4.levels , pb4.title )
#level_points_plot( pb4.f , xn_tab , pb4.x1_min,pb4.x1_max,pb4.x2_min,pb4.x2_max,pb4.nb_points, pb4.levels , pb4.title )
#level_2points_plot( pb4.f , x_tab , xn_tab ,  pb4.x1_min, pb4.x1_max, pb4.x2_min, pb4.x2_max, pb4.nb_points,  pb4.levels ,  pb4.title )

# %% [markdown]
# > What would you do if you would like to find *all* minimizers?

# %% [markdown]
# ### 2.d Polyhedral functions
#
# <a href="#pb5">Problem 5</a> features a convex polydehral function.

# %%
import problem5 as pb5

from plotLib import *
# %matplotlib inline

custom_3dplot( pb5.f, pb5.x1_min,pb5.x1_max,pb5.x2_min,pb5.x2_max,pb5.nb_points, pb5.vmin, pb5.vmax )
level_plot( pb5.f, pb5.x1_min,pb5.x1_max,pb5.x2_min,pb5.x2_max,pb5.nb_points, pb5.levels , pb5.title )
# Out:
# importing notebook from problem5.ipynb

# %% [markdown]
# > Fill the needed 1st order oracles in `problem5.ipynb`. What is different from before?<br/>
# > Run the constant and adaptive stepsize gradient algorithms. Change the initialization and observe the final point.

# %%
import algoProjGradient         # load our algoProjGradient module (from notebook)
reload(algoProjGradient)        # reload the module if changed (and saved)
from algoProjGradient import *  # import all methods of the module into the current environment

import problem5 as pb5
reload(pb5) 


#### Parameter we give at our algorithm (see algoGradient.ipynb)
PREC    = 0.01                     # Sought precision
ITE_MAX = 100                       # Max number of iterations
x0      = np.array( (1.5,0.55 ) )   # Initial point
a = np.array( (-2,-2.0 ) )   # inf bounds 
b = np.array( (3.0,3.0 ) )   # sup bounds
# the interval constraints are a <= x <= b

##### Gradient algorithm
step    =  0.1                     # Stepsize 
x,x_tab = interval_gradient_algorithm(pb5.f , pb5.f_grad , x0 , a, b, step , PREC , ITE_MAX )
### xa,xa_tab = gradient_adaptive_algorithm(pb5.f , pb5.f_grad , x0 , step , PREC , ITE_MAX )
# Out:
# importing notebook from algoProjGradient.ipynb
# importing notebook from problem5.ipynb
# ------------------------------------
#  Constant Stepsize gradient
# ------------------------------------
# START    -- stepsize = 0.1
# gtested = (-1.00,-2.00)
#
# gtested = (-1.00,-2.00)
#
# gtested = (-1.00,2.00)
#
# gtested = (-1.00,-2.00)
#
# gtested = (-1.00,2.00)
#
# gtested = (-1.00,-2.00)
#
# gtested = (-1.00,2.00)
#
# gtested = (-1.00,-2.00)
#
# gtested = (-1.00,2.00)
#
# gtested = (-1.00,-2.00)
#
# gtested = (-1.00,2.00)
#
# gtested = (-1.00,-2.00)
#
# gtested = (-1.00,2.00)
#
# gtested = (-1.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# gtested = (0.00,2.00)
#
# gtested = (0.00,-2.00)
#
# FINISHED -- 99 iterations / 0.002547s -- final value: 0.100000 at point (3.00,0.95)

# %% [markdown]
# ---
# ##### Comparing gradient algorithm and adaptive stepsize method

# %%
from plotLib import *
# %matplotlib inline


##### comparison
level_points_plot( pb5.f , x_tab , pb5.x1_min,pb5.x1_max,pb5.x2_min,pb5.x2_max,pb5.nb_points, pb5.levels , pb5.title )
#level_points_plot( pb5.f , xa_tab , pb5.x1_min,pb5.x1_max,pb5.x2_min,pb5.x2_max,pb5.nb_points, pb5.levels , pb5.title )
#level_2points_plot( pb5.f , x_tab , xa_tab ,  pb5.x1_min, pb5.x1_max, pb5.x2_min, pb5.x2_max, pb5.nb_points,  pb5.levels ,  pb5.title )

# %% [markdown]
# > What would you do to minimize polyhedral functions with interval constraints ?

# %% [markdown]
# # Appendix: <a id="pbs">Problems</a>
#
# The problems we consider in this second lab are minimizations continous functions with positivity and interval constraints using the projected gradients. The functions are identical to the functions froms teh first lab.
#
# We will consider positive constraints $x\ge0$, i.e., $ x_1 \ge 0 $ and $ x_2 \ge 0 $, in particular, in "pb21" (adapted from "pb1" of lab 1) and in "pb4".
#
# We will also test the optimization of these functions with interval constraints of the type $ a_1 \le x_1 \le b_1 $ and  $ a_2 \le x_2 \le b_2 $, where $a_i, b_i, i=1,2$, are floats designing the interval bounds.

# %% [markdown]
# > **1.** <a id="pb21">`problem1`</a> features a simple quadratic function
# $$\begin{array}{rrcll}
# f: & \mathbb{R}^2 & \to &\mathbb{R}\\
# & (x_1,x_2) & \mapsto  & 4 (x_1-3)^2 + 2(x_2 + 0.5)^2
# \end{array}$$
# <center><img src="Fig/1.png" width="50%"></center>
#
#
# > **2.** <a id="pb2">`problem2`</a> features a more involved but very smooth function
# $$\begin{array}{rrcll}
# g: & \mathbb{R}^2 & \to &\mathbb{R}\\
# & (x_1,x_2) & \mapsto  & \log( 1 + \exp(4 (x_1-3)^2 ) + \exp( 2(x_2-1)^2 ) ) - \log(3)
# \end{array}$$
# <center><img src="Fig/2.png" width="50%"></center>
#
#
# > **3.** <a id="pb3">`problem3`</a> features Rosenbrock's smooth but non-convex function
# $$\begin{array}{rrcll}
# r: & \mathbb{R}^2 & \to &\mathbb{R}\\
# & (x_1,x_2) & \mapsto  &  (1-x_1)^2 + 100(x_2-x_1^2)^2
# \end{array}$$
# <center><img src="Fig/3.png" width="50%"></center>
#
#
# > **4.** <a id="pb4">`problem4`</a> features a smooth function with two distinct minimizers
# $$\begin{array}{rrcll}
# t: & \mathbb{R}^2 & \to &\mathbb{R}\\
# & (x_1,x_2) & \mapsto  & (0.6 x_1 + 0.2 x_2)^2 \left((0.6 x_1 + 0.2 x_2)^2 - 4 (0.6 x_1 + 0.2 x_2)+4\right) + (-0.2 x_1 + 0.6 x_2)^2
# \end{array}$$
# <center><img src="Fig/4.png" width="50%"></center>
#
#
# > **5.** <a id="pb5">`problem5`</a> features a polyhedral function
# $$\begin{array}{rrcll}
# p: & \mathbb{R}^2 & \to &\mathbb{R}\\
# & (x_1,x_2) & \mapsto  &  \left| x_1-3 \right|  + 2\left| x_2-1\right| .
# \end{array}$$
# <center><img src="Fig/5.png" width="50%"></center>
